# %%
# Sempre, na primeira célula do notebook, importe as bibliotecas necessárias para a execução do código.

import pandas as pd
import re 
import openpyxl
from datetime import datetime

print("Pandas versão:", pd.__version__)
print("OpenPyXL versão:", openpyxl.__version__)
print("Bibliotecas importadas com sucesso")
# Out:
# Pandas versão: 2.3.3
# OpenPyXL versão: 3.1.5
# Bibliotecas importadas com sucesso

# %%
CAMINHO = "C:/Users/Dell/Documents/GitHub/turma-visualizacao-de-dados/alunos/orlando_castro/semana_04/base_rh.csv"
df = pd.read_csv(
    CAMINHO,
    sep=";",                # separador de campos
    encoding="cp1252",      # encoding para lidar com caracteres acentuados no Windows
    decimal=",",)           # separador decimal
df.head()
# Out:
#    ID_Funcionario                 Nome Departamento        Cargo   Salario  \
# 0               1          Julia Nunes    Logística  Coordenador   9088.34
# 1               2   Sr. Gustavo Duarte           TI      Gerente   8155.98
# 2               3  Srta. Mariana Cunha           RH  Coordenador  14027.93
# 3               4   Ana Sophia da Cruz     Produção      Técnico   6647.97
# 4               5    Dr. Nicolas Pinto     Produção      Gerente   8730.19
#
#   Data_Admissao Genero  Idade Estado_Civil   Status
# 0    13/08/2024      F     43     Solteiro  Inativo
# 1    29/04/2017      F     59     Solteiro  Inativo
# 2    11/12/2024      F     27   Divorciado    Ativo
# 3    16/06/2019      M     50       Casado  Inativo
# 4    29/03/2019      F     62       Casado  Inativo

# %%
print("Dados carregados com sucesso. Número de linhas:", len(df))
print("Colunas disponíveis:", df.columns.tolist())
print("Tipos de dados por coluna:\n", df.dtypes)
# Out:
# Dados carregados com sucesso. Número de linhas: 1000
# Colunas disponíveis: ['ID_Funcionario', 'Nome', 'Departamento', 'Cargo', 'Salario', 'Data_Admissao', 'Genero', 'Idade', 'Estado_Civil', 'Status']
# Tipos de dados por coluna:
#  ID_Funcionario      int64
# Nome               object
# Departamento       object
# Cargo              object
# Salario           float64
# Data_Admissao      object
# Genero             object
# Idade               int64
# Estado_Civil       object
# Status             object
# dtype: object

# %%
print(df.tail(5))  # Mostra os últimos 5 registros do DataFrame
# Out:
#      ID_Funcionario                Nome Departamento     Cargo   Salario  \
# 995             996      Matheus Aragão   Financeiro  Analista  11389.03
# 996             997        Ryan Martins   Financeiro  Analista  14060.42
# 997             998   Isabelly Ferreira           TI   Gerente   2348.73
# 998             999       Thales Farias     Produção  Analista   9430.62
# 999            1000  Sra. Maysa Costela     Produção   Técnico  12549.72
#
#     Data_Admissao Genero  Idade Estado_Civil   Status
# 995    06/05/2022      F     26        Viúvo    Ativo
# 996    05/06/2023      F     37        Viúvo    Ativo
# 997    29/12/2023      F     58     Solteiro  Inativo
# 998    25/12/2019      M     41     Solteiro    Ativo
# 999    14/11/2022      M     46        Viúvo  Inativo

# %%
print("quantidade de registro nulos por coluna:\n", df.isnull().sum())

print("Percentual de nulos por coluna:\n", (df.isnull().sum() / len(df)) * 100)
# Out:
# quantidade de registro nulos por coluna:
#  ID_Funcionario    0
# Nome              0
# Departamento      0
# Cargo             0
# Salario           0
# Data_Admissao     0
# Genero            0
# Idade             0
# Estado_Civil      0
# Status            0
# dtype: int64
# Percentual de nulos por coluna:
#  ID_Funcionario    0.0
# Nome              0.0
# Departamento      0.0
# Cargo             0.0
# Salario           0.0
# Data_Admissao     0.0
# Genero            0.0
# Idade             0.0
# Estado_Civil      0.0
# Status            0.0
# dtype: float64

# %%
print(df.describe().round(2)) # exibe as estatísticas descritivas para as colunas numéricas, arredondando os valores para 2 casas decimais
# Out:
#        ID_Funcionario   Salario    Idade
# count         1000.00   1000.00  1000.00
# mean           500.50   8579.95    41.40
# std            288.82   3657.37    13.67
# min              1.00   2000.71    18.00
# 25%            250.75   5564.54    30.00
# 50%            500.50   8571.13    41.00
# 75%            750.25  11554.63    53.00
# max           1000.00  14954.51    65.00

# %%
print("Valores únicos por coluna:")
print(df.nunique())
# Out:
# Valores únicos por coluna:
# ID_Funcionario    1000
# Nome               976
# Departamento         6
# Cargo                5
# Salario           1000
# Data_Admissao      878
# Genero               2
# Idade               48
# Estado_Civil         4
# Status               2
# dtype: int64
