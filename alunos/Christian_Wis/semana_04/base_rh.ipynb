# %%
#biblioteca de analise de dados
import pandas as pd      

#expressao regulares (para limpar texto)
import re

#para eu trabalhar com datas
from datetime import datetime


#confirmar que as importaçoes funcionaram
print(" pandas versao:", pd.__version__)

print("bibliotecas importadas com sucesso")
# Out:
#  pandas versao: 3.0.2
#  bibliotecas importadas com sucesso

# %%
# pd.read_csv       #para ler arquivos .csv
# CAMINHO = onde esta o arquivo. como ele esta na mesma pata que este notebook
# basta passar o nome do arquivo, entre aspas para a funçao ler o arquivo e  criar um DataFrame (tabela) com os dados


CAMINHO = r"C:\Users\Mirtu\Desktop\ESTUDOS PYTHON\GIT\turma-visualizacao-de-dados\alunos\Christian_Wis\semana_04\base_rh.csv"

df = pd.read_csv(CAMINHO,
    sep=";",                  #separador de colunas é ";" e nao ","cache_dates=
    encoding='cp1252'         # encoding do windows para ler acentos
    decimal=","               # virugla é como separador decimas
)


print("Dados carregados com sucesso!")

print(f"TOtal de linhas: {df.shape[0]}")
print(f"TOtal de linhas: {df.shape[1]}")
# Out:
#   Cell In[8], line 10
#     encoding='cp1252'         # encoding do windows para ler acentos
#              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
